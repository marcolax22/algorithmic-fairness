# %% [markdown]
# # Fairness Problematic

# %%
# -------------------------------------------------------------------------------
# import packages
import pandas as pd 
import numpy as np
import import_ipynb
import seaborn as sns

# -------------------------------------------------------------------------------
# import scripts
from data_processing import hiring_data
import functions.fairness_testing as fairness
# Out:
# Index(['Id', 'gender', 'nationality', 'sport', 'ind-degree', 'company'], dtype='object')

# %% [markdown]
# ## Distribution of Variables

# %%
fairness.fairness_plot(hiring_data, hiring_data['gender'], hiring_data['decision'])

# %% [markdown]
# ## Correlation between the variables

# %%
fairness.correlation_matrix(hiring_data)
