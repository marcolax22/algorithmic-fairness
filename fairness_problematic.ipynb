# %% [markdown]
# # Fairness Issue Dataset

# %%
# -------------------------------------------------------------------------------
# import packages
import pandas as pd 
import numpy as np
import import_ipynb
import seaborn as sns

# -------------------------------------------------------------------------------
# import scripts
from data_processing import hiring_data

# %%
hiring_data
# Out:
#         Id  gender  age  nationality  sport  ind-university_grade  \
# 0     3130       0   24            2      6                    70
# 1     2229       1   26            2      3                    67
# 2     2197       0   23            1      5                    67
# 3      505       1   24            1      1                    70
# 4     2311       0   26            2      3                    59
# ...    ...     ...  ...          ...    ...                   ...
# 3995  2956       0   28            1      5                    63
# 3996  1012       0   27            1      7                    62
# 3997    78       1   24            0      4                    60
# 3998   101       0   22            1      7                    66
# 3999   601       1   28            1      2                    58
#
#       ind-debateclub  ind-programming_exp  ind-international_exp  \
# 0                  0                    0                      0
# ...

# %% [markdown]
# ## Fairness

# %%
gender_matrix = pd.crosstab(hiring_data['gender'], hiring_data['decision'])
gender_matrix
# Out:
# decision     0    1
# gender
# 0         1298  492
# 1         1377  750
# 2           58   25

# %%
gender_matrix = pd.crosstab(hiring_data['gender'], hiring_data['ind-programming_exp'])
gender_matrix

gender_matrix = pd.crosstab(hiring_data['gender'], hiring_data['ind-exact_study'])
gender_matrix
# Out:
# ind-exact_study     0     1
# gender
# 0                 703  1087
# 1                1408   719
# 2                  38    45

# %%
# gender to numerical categorical variable
hiring_data = hiring_data.copy()
hiring_data['gender_numerical'] = hiring_data['gender'].map({'male': 0, 'female': 1, 'other': 2})

# %%
gender_matrix = pd.crosstab(hiring_data['gender_numerical'], hiring_data['decision'])
gender_matrix
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Calculate correlations
correlation_matrix = hiring_data.corr()
correlation_matrix

# show heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >
