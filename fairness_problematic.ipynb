# %% [markdown]
# # Fairness Problematic

# %%
# -------------------------------------------------------------------------------
# import packages
import pandas as pd 
import numpy as np
import import_ipynb
import seaborn as sns
import matplotlib.pyplot as plt

# -------------------------------------------------------------------------------
# import scripts
from data_processing import hiring_data
import functions.fairness_testing as fairness

# %% [markdown]
# ## Distribution of Variables

# %%
fairness.fairness_plot(hiring_data, hiring_data['gender'], hiring_data['decision'])

# %%
# percentage of each gender
hiring_data['gender'].value_counts(normalize=True)
# Out:
# gender
# 0    0.543018
# 1    0.456982
# Name: proportion, dtype: float64

# %%
# when decision equals 1
hiring_data[hiring_data['decision'] == 1]['gender'].value_counts(normalize=True)
# Out:
# gender
# 0    0.603865
# 1    0.396135
# Name: proportion, dtype: float64

# %% [markdown]
# ## Correlation between the variables

# %%
# drop id and decision
hiring_data = hiring_data.drop(columns=['Id', 'decision'])
fig = fairness.correlation_matrix(hiring_data)
fig

# save fig as png
fig.savefig("graphics/correlation_matrix.png", dpi=300, bbox_inches='tight')
